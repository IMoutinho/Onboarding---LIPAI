# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelozanchetta/EDS104/blob/main/Lab2_Atividade_Dados_Exploratorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laboratório 2 - Atividade 1**
#
# A exploração de dados refere-se à investigação preliminar dos dados para entender melhor suas características específicas.
#
# Há duas motivações principais para a exploração de dados:
#
# *   Auxiliar na seleção de etapas de pré-processamento com as técnicas de análise de dados
# *   Auxiliar a renconhecer padrões nos dados

# %% [markdown]
# ---
# # **Análise dos Dados**
# ---

# %% [markdown]
# Nesta aula usaremos os dados do dataset Iris, que contêm informações sobre 150 flores de Iris, 50 de cada uma das três espécies de Iris: Setosa, Versicolour e Virginica. Cada flor é caracterizada por cinco atributos:
# * comprimento da sépala em centímetros
# * largura da sépala em centímetros
# * comprimento da pétala em centímetros
# * largura da pétala em centímetros
# * classe (Setosa, Versicolour, Virginica)
#
# *Deve fazer download do arquivo no link:* https://github.com/pandas-dev/pandas/blob/main/pandas/tests/io/data/csv/iris.csv
#
# A Figura 1 apresenta os três tipos da flor da base Iris: Versicolor, Setosa e Virginica:
#
# ![2018-10-17-classificacao-iris-01.png](data:image/png;base64,...)
#
# Fonte: https://www.datacamp.com/community/tutorials/machine-learning-in-r

# %% [markdown]
# # **Análise e Estudo de Métricas Estatísticas Obtidos no Dataset**

# %% [markdown]
# As métricas estatísticas capturam várias características de um conjunto potencialmente grande de valores com um único número ou um pequeno conjunto de números. Nesta aula, vamos explorar os dados do dataset Iris.

# %%
# montar o drive do google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# O código usa a biblioteca Pandas para ler o arquivo CSV e armazená-lo em um objeto DataFrame denominado em nosso exemplo "dataset":

# %%
import pandas as pd
dataset = pd.read_csv("/content/drive/MyDrive/Dados_Exploratorios_dataset-cvs/datasets/iris.csv")

# %% [markdown]
# Então, insere o nome das colunas e exibe as primeiras linhas dos dados (sepal length - comprimento da sépala, sepal width - largura da sépala, petal length - comprimento da pétala e petal width - largura da pétala):

# %%
dataset.columns = ['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'class']
dataset.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# Para verificar o número de amostras e número de características no dataset:

# %%
dataset.shape
# Out:
# (150, 5)

# %% [markdown]
# Mostrar os dez primeiros exemplos (amostras) da base de dados:

# %%
print(dataset.head(10))
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %% [markdown]
# Mostrar as 5 últimas amostras da base de dados:

# %%
dataset.tail(5)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth           class
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# Exibir as colunas e outras opções do Pandas Data Frame:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Exibir o tipo de cada coluna:

# %%
dataset.dtypes
# Out:
# sepalLength    float64
# sepalWidth     float64
# petalLength    float64
# petalWidth     float64
# class           object
# dtype: object

# %% [markdown]
# Faz busca por exemplo de uma determinada característica:

# %%
dataset[(dataset.sepalLength == 4.7)]
# Out:
#     sepalLength  sepalWidth  petalLength  petalWidth        class
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 29          4.7         3.2          1.6         0.2  Iris-setosa

# %% [markdown]
# Faz busca usando o método query na base Iris:

# %%
dataset.query('sepalLength == 4.7')
# Out:
#     sepalLength  sepalWidth  petalLength  petalWidth        class
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 29          4.7         3.2          1.6         0.2  Iris-setosa

# %% [markdown]
# Retira colunas escolhidas

# %%
dataset.drop(columns = ['sepalLength', 'class'])
# Out:
#      sepalWidth  petalLength  petalWidth
# 0           3.5          1.4         0.2
# 1           3.0          1.4         0.2
# 2           3.2          1.3         0.2
# 3           3.1          1.5         0.2
# 4           3.6          1.4         0.2
# ..          ...          ...         ...
# 145         3.0          5.2         2.3
# 146         2.5          5.0         1.9
# 147         3.0          5.2         2.0
# 148         3.4          5.4         2.3
# 149         3.0          5.1         1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# Para encontrar o número de valores únicos correspondente para cada coluna no DataFrame:

# %%
for column in dataset.columns:
  num_unique_values = dataset[column].nunique()
  print(f'Número de valores únicos em {column}: {num_unique_values}')
# Out:
# Número de valores únicos em sepalLength: 35
# Número de valores únicos em sepalWidth: 23
# Número de valores únicos em petalLength: 43
# Número de valores únicos em petalWidth: 22
# Número de valores únicos em class: 3

# %% [markdown]
# Para cada atributo quantitativo, calcular medidas de estatística, como por exemplo, medidas de tendência central.

# %%
from pandas.api.types import is_numeric_dtype

for col in dataset.columns:
    if is_numeric_dtype(dataset[col]):
        print('%s:' % (col))
        # medidas de tendência central
        print('\t Média = %.2f' % dataset[col].mean())
        print('\t Mediana = %.2f' % dataset[col].median())

        print('\t Desvio padrão = %.2f' % dataset[col].std())
        print('\t Variância = %.2f' % dataset[col].var())
        print('\t Mínimo = %.2f' % dataset[col].min())
        print('\t Máximo = %.2f' % dataset[col].max())
# Out:
# sepalLength:
# 	 Média = 5.84
# 	 Mediana = 5.80
# 	 Desvio padrão = 0.83
# 	 Variância = 0.69
# 	 Mínimo = 4.30
# 	 Máximo = 7.90
# sepalWidth:
# 	 Média = 3.05
# 	 Mediana = 3.00
# 	 Desvio padrão = 0.43
# 	 Variância = 0.19
# 	 Mínimo = 2.00
# 	 Máximo = 4.40
# petalLength:
# 	 Média = 3.76
# 	 Mediana = 4.35
# 	 Desvio padrão = 1.76
# 	 Variância = 3.11
# 	 Mínimo = 1.00
# 	 Máximo = 6.90
# petalWidth:
# 	 Média = 1.20
# 	 Mediana = 1.30
# 	 Desvio padrão = 0.76
# 	 Variância = 0.58
# 	 Mínimo = 0.10
# 	 Máximo = 2.50

# %% [markdown]
# Para o atributo qualitativo (classe), conta a frequência de cada um de seus valores distintos.

# %%
dataset['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Também é possível exibir o resumo de todos os atributos simultaneamente em uma tabela usando a função describe(). Se um atributo for quantitativo, ele exibirá sua média, desvio padrão e vários valores de quantis (incluindo mínimo, mediano e máximo). Se um atributo for qualitativo, ele exibirá seu número de valores exclusivos e os valores principais (mais frequentes).

# %%
dataset.describe(include='all')
# Out:
#         sepalLength  sepalWidth  petalLength  petalWidth        class
# count    150.000000  150.000000   150.000000  150.000000          150
# unique          NaN         NaN          NaN         NaN            3
# top             NaN         NaN          NaN         NaN  Iris-setosa
# freq            NaN         NaN          NaN         NaN           50
# mean       5.843333    3.054000     3.758667    1.198667          NaN
# std        0.828066    0.433594     1.764420    0.763161          NaN
# min        4.300000    2.000000     1.000000    0.100000          NaN
# 25%        5.100000    2.800000     1.600000    0.300000          NaN
# 50%        5.800000    3.000000     4.350000    1.300000          NaN
# 75%        6.400000    3.300000     5.100000    1.800000          NaN
# max        7.900000    4.400000     6.900000    2.500000          NaN

# %% [markdown]
# Para verificar se há valores ausentes:

# %%
dataset.isnull().sum()
# Out:
# sepalLength    0
# sepalWidth     0
# petalLength    0
# petalWidth     0
# class          0
# dtype: int64

# %% [markdown]
# Examina linhas com valores ausentes em qualquer coluna:

# %%
dataset.loc[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [sepalLength, sepalWidth, petalLength, petalWidth, class]
# Index: []

# %% [markdown]
# Sustitui os valores NaN por valores zeros (0s):

# %%
dataset.fillna(0)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Para estatísticas multivariadas, podemos calcular a covariância e a correlação entre pares de atributos. Essas medidas pode avaliar
# relações entre atributos.

# %%
print('Covariance:')
dataset.cov(numeric_only=True)
# Out:
# Covariance:
#              sepalLength  sepalWidth  petalLength  petalWidth
# sepalLength     0.685694   -0.039268     1.273682    0.516904
# sepalWidth     -0.039268    0.188004    -0.321713   -0.117981
# petalLength     1.273682   -0.321713     3.113179    1.296387
# petalWidth      0.516904   -0.117981     1.296387    0.582414

# %%
print('Correlation:')
dataset.corr(numeric_only=True)
# Out:
# Correlation:
#              sepalLength  sepalWidth  petalLength  petalWidth
# sepalLength     1.000000   -0.109369     0.871754    0.817954
# sepalWidth     -0.109369    1.000000    -0.420516   -0.356544
# petalLength     0.871754   -0.420516     1.000000    0.962757
# petalWidth      0.817954   -0.356544     0.962757    1.000000

# %% [markdown]
# ---
# # **Visualização dos dados**
# ---

# %% [markdown]
# **Histograma**
#
#
# Visualização da coluna de destino
#
# Nossa coluna de destino será a coluna Species (Espécies) porque, no final, precisaremos do resultado de acordo apenas com as espécies. Vamos ver um gráfico de contagem de espécies.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='class', data=dataset, )
plt.show()

# %% [markdown]
# Analisar a relação entre o comprimento da sépala e a largura da sépala e entre o comprimento da pétala e a largura da pétala.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='sepalLength', y='sepalWidth',
                hue='class', data=dataset, )

# Legenda fora da figura
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()
# A espécie Setosa tem comprimento de sépala menor, mas largura de sépala maior.
# A espécie Versicolor está no meio das outras duas espécies em termos de comprimento e largura das sépalas
# A espécie Virginica tem comprimento de sépala maior, mas largura de sépala menor.

# %% [markdown]
# Comparação entre o comprimento e a largura das pétalas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='petalLength', y='petalWidth',
                hue='class', data=dataset, )

plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %% [markdown]
# **Box plots**

# %%
import pandas
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# gerando bloxplot para os atributos da Iris
dataset.plot(kind='box')
pyplot.show()

# %% [markdown]
# **HeatMap**

# %% [markdown]
# Um Heatmap 2-D é uma ferramenta de visualização de dados que ajuda a representar a magnitude de uma matriz sob a forma de uma tabela colorida.

# %%
import seaborn as sb
import matplotlib.pyplot as plt

#Calcula os coeficientes de correlação par a par de todas as colunas no DataFrame e garante que somente as colunas numéricas sejam incluídas no cálculo.
corr = dataset.corr(numeric_only=True)
f,ax = plt.subplots(figsize=(9,7))
sb.heatmap(corr, annot=True, square=True, fmt='.1g')
plt.show()

# %% [markdown]
# **Scatter plots**

# %% [markdown]
# Para cada par de atributos, pode ser usado um gráfico de dispersão para visualizar sua distribuição conjunta.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(12,12))
index = 0
for i in range(3):
    for j in range(i+1,4):
        ax1 = int(index/2)
        ax2 = index % 2
        axes[ax1][ax2].scatter(dataset[dataset.columns[i]], dataset[dataset.columns[j]], color='blue')
        axes[ax1][ax2].set_xlabel(dataset.columns[i])
        axes[ax1][ax2].set_ylabel(dataset.columns[j])
        index = index + 1

# %% [markdown]
# As coordenadas paralelas podem ser usadas para exibir todos os pontos de dados simultaneamente.

# %%
from pandas.plotting import parallel_coordinates
# %matplotlib inline

parallel_coordinates(dataset, 'class')
# Out:
# <Axes: >

# %% [markdown]
# Os histogramas permitem ver a distribuição de dados para várias colunas. Ele pode ser usado para análises uni e bivariadas.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Sepal Length")
axes[0,0].hist(dataset['sepalLength'], bins=7)

axes[0,1].set_title("Sepal Width")
axes[0,1].hist(dataset['sepalWidth'], bins=5);

axes[1,0].set_title("Petal Length")
axes[1,0].hist(dataset['petalLength'], bins=6);

axes[1,1].set_title("Petal Width")
axes[1,1].hist(dataset['petalWidth'], bins=6);

# %% [markdown]
# A distribuição do comprimento da pétala:

# %%
import seaborn as sns
sns.histplot(dataset['petalLength'], bins=15, kde=True, color='lightgreen')
# Out:
# <Axes: xlabel='petalLength', ylabel='Count'>

# %% [markdown]
# A distribuição cumulativa empírica é uma função que explica como valores associadas a uma probabilidade. Dados os exemplos, o primeiro gráfico, temos que SepalLength (Comprimento da sépala) tem 40% dos dados tem 5,5 cm. Essa ferramenta traz um panorama empírico da característica.

# %%
# Empirical Cumulative Distribution
# visualising ECDF

from mlxtend.plotting import ecdf
import matplotlib.pyplot as plt

# Criando uma figura e eixos para os subplots
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(13, 40))

# Ajustando o espaçamento entre os subplots
plt.subplots_adjust(right=2)
plt.subplots_adjust(top=2)

# Limpando a figura
plt.clf()

# Iterando sobre cada coluna do dataset
for i, feature in enumerate(dataset.columns, 1):
    # Adicionando um subplot para cada coluna
    plt.subplot(len(dataset.columns), 3, i)

    # Criando um gráfico de funções de distribuição cumulativa
    ecdf(dataset[feature])

    # Adicionando título ao subplot
    plt.title(f'{feature}', size=15, fontsize=12, fontweight='medium')

    # Removendo as grades do gráfico
    plt.grid(False)

    # Ajustando o tamanho das etiquetas nos eixos x e y
    plt.tick_params(axis='x', labelsize=8)
    plt.tick_params(axis='y', labelsize=8)

# Ajustando o layout dos subplots
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# **Outliers**: Na visualização da distribuição de cada característica numérica usando gráficos box plots, nota-se alguns ponts além do gráfico podem ser considerados outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x=dataset['sepalWidth'], color='lightgreen')
# Out:
# <Axes: xlabel='sepalWidth'>

# %% [markdown]
# ---
# # **Amostragem**
# ---

# %% [markdown]
# A amostragem é uma abordagem comumente usada para selecionar um subconjunto de dados objetos de dados a serem analisados. Pode ser usada para a investigação preliminar dos dados e para a análise final dos dados. Os dados são divididos em partes no qual pode selecionar o número da parte que deseja amostrar.

# %%
sample_data = dataset.sample(n=100)

# %% [markdown]
# ---
# # **Exercícios**
# ---

# %% [markdown]
# Use um dos datasets Wine ou Boston para avaliação das análise empregadas em nossa aula. Os datasets podem ser baixados do site da UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets

# %% [markdown]
# 1) Escolha um novo dataset e construa um programa que calcule as medidas estatísticas. Procure usar as funções apresentadas nessa atividade, assim como, outras que estão disponíveis nas bibliotecas do Python (https://www.scaler.com/topics/pandas/statistical-functions-in-pandas/).

# %%
dataset2 = pd.read_csv("/content/drive/MyDrive/Dados_Exploratorios_dataset-cvs/datasets/wine.data")
dataset2.columns = ['Class', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_of_ash', 'Magnesium', 'Total_phenols',
                    'Flavanoids','Nonflavanoid_phenols',  'Proanthocyanins', 'Color_intensity', 'Hue', 'OD280/OD315_of_diluted wines', 'Proline' ]
dataset2.head()
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    13.20        1.78  2.14               11.2        100
# 1      1    13.16        2.36  2.67               18.6        101
# 2      1    14.37        1.95  2.50               16.8        113
# 3      1    13.24        2.59  2.87               21.0        118
# 4      1    14.20        1.76  2.45               15.2        112
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color_intensity   Hue  OD280/OD315_of_diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# ...

# %%
dataset2.describe()
# Out:
#             Class     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
print('Correlation:')
dataset2.corr(numeric_only=True)
# Out:
# Correlation:
#                                  Class   Alcohol  Malic_acid       Ash  \
# Class                         1.000000 -0.321238    0.436127 -0.048260
# Alcohol                      -0.321238  1.000000    0.099963  0.210964
# Malic_acid                    0.436127  0.099963    1.000000  0.164955
# Ash                          -0.048260  0.210964    0.164955  1.000000
# Alcalinity_of_ash             0.513963 -0.303350    0.286148  0.446698
# Magnesium                    -0.198944  0.258742   -0.049049  0.287107
# Total_phenols                -0.717933  0.284543   -0.333512  0.128176
# Flavanoids                   -0.846485  0.230133   -0.409324  0.114084
# Nonflavanoid_phenols          0.487215 -0.151445    0.291501  0.187354
# Proanthocyanins              -0.494887  0.127561   -0.217975  0.008082
# Color_intensity               0.268562  0.547883    0.250053  0.258643
# Hue                          -0.617690 -0.075375   -0.560854 -0.075181
# ...

# %%
print('Covariance:')
dataset2.cov(numeric_only=True)
# Out:
# Covariance:
#                                    Class     Alcohol  Malic_acid        Ash  \
# Class                           0.599063   -0.201098    0.377834  -0.010275
# Alcohol                        -0.201098    0.654171    0.090498   0.046937
# Malic_acid                      0.377834    0.090498    1.252865   0.050790
# Ash                            -0.010275    0.046937    0.050790   0.075669
# Alcalinity_of_ash               1.327099   -0.818511    1.068508   0.409929
# Magnesium                      -2.182524    2.966239   -0.778172   1.119429
# Total_phenols                  -0.348110    0.144175   -0.233862   0.022088
# Flavanoids                     -0.654293    0.185884   -0.457547   0.031340
# Nonflavanoid_phenols            0.047007   -0.015269    0.040672   0.006424
# Proanthocyanins                -0.218923    0.058968   -0.139447   0.001271
# Color_intensity                 0.483171    1.030037    0.650585   0.165379
# ...

# %%
dataset2['Class'].value_counts()
# Out:
# Class
# 2    71
# 1    58
# 3    48
# Name: count, dtype: int64

# %%
from pandas.api.types import is_numeric_dtype

estatisticas = {}
for col in dataset2.columns:
    if is_numeric_dtype(dataset2[col]):
        estatisticas[col] = {
            'Média': dataset2[col].mean(),
            'Mediana': dataset2[col].median(),
            'Desvio padrão': dataset2[col].std(),
            'Variância': dataset2[col].var(),
            'Mínimo': dataset2[col].min(),
            'Máximo': dataset2[col].max()
        }

print("Estatisticas Gerais")
for col, valores in estatisticas.items():
    print(f"{col}:")
    for metrica, valor in valores.items():
        print(f"\t {metrica} = {valor:.2f}")
# Out:
# Estatisticas Gerais
# Class:
# 	 Média = 1.94
# 	 Mediana = 2.00
# 	 Desvio padrão = 0.77
# 	 Variância = 0.60
# 	 Mínimo = 1.00
# 	 Máximo = 3.00
# Alcohol:
# 	 Média = 12.99
# 	 Mediana = 13.05
# 	 Desvio padrão = 0.81
# 	 Variância = 0.65
# 	 Mínimo = 11.03
# 	 Máximo = 14.83
# Malic_acid:
# 	 Média = 2.34
# 	 Mediana = 1.87
# 	 Desvio padrão = 1.12
# 	 Variância = 1.25
# 	 Mínimo = 0.74
# 	 Máximo = 5.80
# Ash:
# 	 Média = 2.37
# 	 Mediana = 2.36
# 	 Desvio padrão = 0.28
# 	 Variância = 0.08
# 	 Mínimo = 1.36
# 	 Máximo = 3.23
# Alcalinity_of_ash:
# 	 Média = 19.52
# 	 Mediana = 19.50
# 	 Desvio padrão = 3.34
# 	 Variância = 11.13
# 	 Mínimo = 10.60
# 	 Máximo = 30.00
# Magnesium:
# 	 Média = 99.59
# 	 Mediana = 98.00
# 	 Desvio padrão = 14.17
# 	 Variância = 200.90
# 	 Mínimo = 70.00
# 	 Máximo = 162.00
# Total_phenols:
# 	 Média = 2.29
# 	 Mediana = 2.35
# 	 Desvio padrão = 0.63
# 	 Variância = 0.39
# 	 Mínimo = 0.98
# 	 Máximo = 3.88
# Flavanoids:
# 	 Média = 2.02
# ...

# %%
print("Estatistica da Intensidade da Coloração")
estatisticas_color = estatisticas['Color_intensity']
for metrica, valor in estatisticas_color.items():
    print(f"{metrica} da Cor: {valor:.2f}")
# Out:
# Estatistica da Intensidade da Coloração
# Média da Cor: 5.05
# Mediana da Cor: 4.68
# Desvio padrão da Cor: 2.32
# Variância da Cor: 5.40
# Mínimo da Cor: 1.28
# Máximo da Cor: 13.00

# %% [markdown]
# 2) Use o dataset escolhido e mostre por meio das representações gráficas (histogramas) as principais características. Procure usar as funções apresentadas nesta atividade.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Alcohol")
axes[0,0].hist(dataset2['Alcohol'], bins=10, color='skyblue', edgecolor='black')

axes[0,1].set_title("Malic Acid")
axes[0,1].hist(dataset2['Malic_acid'], bins=10, color='salmon', edgecolor='black')

axes[1,0].set_title("Color Intensity")
axes[1,0].hist(dataset2['Color_intensity'], bins=10, color='plum', edgecolor='black')

axes[1,1].set_title("Proline")
axes[1,1].hist(dataset2['Proline'], bins=10, color='lightgreen', edgecolor='black')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(6, 2, figsize=(12, 30))
index = 0

selecao = 'Ash'

for col in dataset2.columns:
    if col == selecao or col == 'Class':
        continue

    ax1 = int(index / 2)
    ax2 = index % 2

    axes[ax1][ax2].scatter(dataset2[col], dataset2[selecao], color='blue', alpha=0.6)

    axes[ax1][ax2].set_xlabel(col)
    axes[ax1][ax2].set_ylabel(selecao)
    axes[ax1][ax2].set_title(f"{col} vs {selecao}")

    index = index + 1

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x=dataset2['Color_intensity'], color='purple')
# Out:
# <Axes: xlabel='Color_intensity'>

# %%
import seaborn as sb
import matplotlib.pyplot as plt

corr = dataset2.corr(numeric_only=True)
f,ax = plt.subplots(figsize=(9,7))
sb.heatmap(corr, annot=True, square=True, fmt='.1g')
plt.show()

# %% [markdown]
# 3) O dataset Iris não possui valores ausentes. A base escolhida também pode conter todos os descritores por cada amostra. Use um dataset e sobre as amostras impute valores ausentes usando a média, mediana ou outras medidas.

# %%
print(dataset2.isnull().sum())
# Out:
# Class                           0
# Alcohol                         0
# Malic_acid                      0
# Ash                             0
# Alcalinity_of_ash               0
# Magnesium                       0
# Total_phenols                   0
# Flavanoids                      0
# Nonflavanoid_phenols            0
# Proanthocyanins                 0
# Color_intensity                 0
# Hue                             0
# OD280/OD315_of_diluted wines    0
# Proline                         0
# dtype: int64

# %%
import numpy as np

dataset2_faltante = dataset2.copy()
dataset2_faltante.iloc[0:70, :] = np.nan
print(dataset2_faltante.isnull().sum())
# Out:
# Class                           70
# Alcohol                         70
# Malic_acid                      70
# Ash                             70
# Alcalinity_of_ash               70
# Magnesium                       70
# Total_phenols                   70
# Flavanoids                      70
# Nonflavanoid_phenols            70
# Proanthocyanins                 70
# Color_intensity                 70
# Hue                             70
# OD280/OD315_of_diluted wines    70
# Proline                         70
# dtype: int64

# %%
medias_das_colunas = dataset2_faltante.mean()
dataset2_faltante = dataset2_faltante.fillna(medias_das_colunas)
print(dataset2_faltante.isnull().sum())
# Out:
# Class                           0
# Alcohol                         0
# Malic_acid                      0
# Ash                             0
# Alcalinity_of_ash               0
# Magnesium                       0
# Total_phenols                   0
# Flavanoids                      0
# Nonflavanoid_phenols            0
# Proanthocyanins                 0
# Color_intensity                 0
# Hue                             0
# OD280/OD315_of_diluted wines    0
# Proline                         0
# dtype: int64

# %% [markdown]
# 4) Após aplicação das operações, faça a representação gráfica com histogramas das novas características dos dados analisados.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Alcohol")
axes[0,0].hist(dataset2_faltante['Alcohol'], bins=10, color='skyblue', edgecolor='black')

axes[0,1].set_title("Malic Acid")
axes[0,1].hist(dataset2_faltante['Malic_acid'], bins=10, color='salmon', edgecolor='black')

axes[1,0].set_title("Color Intensity")
axes[1,0].hist(dataset2_faltante['Color_intensity'], bins=10, color='plum', edgecolor='black')

axes[1,1].set_title("Proline")
axes[1,1].hist(dataset2_faltante['Proline'], bins=10, color='lightgreen', edgecolor='black')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(6, 2, figsize=(12, 30))
index = 0

selecao = 'Ash'

for col in dataset2_faltante.columns:
    if col == selecao or col == 'Class':
        continue

    ax1 = int(index / 2)
    ax2 = index % 2

    axes[ax1][ax2].scatter(dataset2_faltante[col], dataset2_faltante[selecao], color='blue', alpha=0.6)

    axes[ax1][ax2].set_xlabel(col)
    axes[ax1][ax2].set_ylabel(selecao)
    axes[ax1][ax2].set_title(f"{col} vs {selecao}")

    index = index + 1

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x=dataset2_faltante['Color_intensity'], color='purple')
# Out:
# <Axes: xlabel='Color_intensity'>

# %%
import seaborn as sb
import matplotlib.pyplot as plt

corr = dataset2_faltante.corr(numeric_only=True)
f,ax = plt.subplots(figsize=(9,7))
sb.heatmap(corr, annot=True, square=True, fmt='.1g')
plt.show()

# %% [markdown]
# 5) Compare os resultados obtidos usando um gráfico box plot. Que atributos possuem distribuições mais simétricas? Há a presença de valores extremos, denominados de outliers, para os atributos?

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
coluna_alvo = 'Alcohol'
dataset2[[coluna_alvo]].plot(kind='box', ax=axes[0], color='blue')
axes[0].set_title(f"Sistema Original ({coluna_alvo})")
dataset2_faltante[[coluna_alvo]].plot(kind='box', ax=axes[1], color='red')
axes[1].set_title(f"Sistema Sistema Corrigido pela Média  ({coluna_alvo})")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
coluna_alvo = 'Color_intensity'
dataset2[[coluna_alvo]].plot(kind='box', ax=axes[0], color='blue')
axes[0].set_title(f"Sistema Original ({coluna_alvo})")
dataset2_faltante[[coluna_alvo]].plot(kind='box', ax=axes[1], color='red')
axes[1].set_title(f"Sistema Sistema Corrigido pela Média  ({coluna_alvo})")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
coluna_alvo = 'Hue'
dataset2[[coluna_alvo]].plot(kind='box', ax=axes[0], color='blue')
axes[0].set_title(f"Sistema Original ({coluna_alvo})")
dataset2_faltante[[coluna_alvo]].plot(kind='box', ax=axes[1], color='red')
axes[1].set_title(f"Sistema Corrigido pela Média ({coluna_alvo})")
plt.tight_layout()
plt.show()

# %% [markdown]
# 6) No dataset escolhido selecione intervalos de amostragem (10%, 30% e 50% - Progressiva) e faça análises sobre os dados em relação as métricas estatísticas. O que você pode observar sobre os subconjuntos em relação as métricas estatísticas com a nova composição dos dados?

# %%
import pandas as pd

print("População (100%)")
dataset2.describe()
# Out:
# População (100%)
#             Class     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
import pandas as pd

dataset2_10 = dataset2.sample(frac=0.10)
print("População (10%)")
dataset2_10.describe()
# Out:
# População (10%)
#            Class    Alcohol  Malic_acid        Ash  Alcalinity_of_ash  \
# count  18.000000  18.000000   18.000000  18.000000          18.000000
# mean    1.944444  13.188333    2.423889   2.328889          18.488889
# std     0.937595   0.778915    1.075591   0.197153           2.859841
# min     1.000000  11.820000    1.290000   1.880000          11.400000
# 25%     1.000000  12.830000    1.562500   2.207500          16.850000
# 50%     2.000000  13.255000    1.840000   2.320000          19.500000
# 75%     3.000000  13.497500    3.520000   2.442500          20.000000
# max     3.000000  14.750000    4.280000   2.680000          22.500000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count   18.000000      18.000000   18.000000             18.000000
# mean    99.166667       2.120556    1.839444              0.364444
# std     11.961949       0.600808    1.025501              0.110891
# ...

# %%
import pandas as pd

dataset2_30 = dataset2.sample(frac=0.30)
print("População (30%)")
dataset2_30.describe()
# Out:
# População (30%)
#            Class    Alcohol  Malic_acid        Ash  Alcalinity_of_ash  \
# count  53.000000  53.000000   53.000000  53.000000          53.000000
# mean    1.981132  12.966604    2.329245   2.367547          19.632075
# std     0.771875   0.801722    1.164205   0.220915           2.814712
# min     1.000000  11.410000    0.740000   1.920000          11.200000
# 25%     1.000000  12.420000    1.640000   2.240000          18.500000
# 50%     2.000000  13.050000    1.810000   2.350000          20.000000
# 75%     3.000000  13.520000    2.560000   2.500000          21.000000
# max     3.000000  14.830000    5.510000   2.920000          25.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count   53.000000      53.000000   53.000000             53.000000
# mean    98.490566       2.172453    1.939623              0.387547
# std     15.644639       0.610728    0.941709              0.121938
# ...

# %%
import pandas as pd

dataset2_50 = dataset2.sample(frac=0.50)
print("População (50%)")
dataset2_50.describe()
# Out:
# População (50%)
#            Class    Alcohol  Malic_acid        Ash  Alcalinity_of_ash  \
# count  88.000000  88.000000   88.000000  88.000000          88.000000
# mean    1.977273  13.065568    2.484545   2.365568          19.631818
# std     0.801970   0.844152    1.163834   0.269422           3.416072
# min     1.000000  11.030000    0.900000   1.700000          11.400000
# 25%     1.000000  12.320000    1.632500   2.210000          17.200000
# 50%     2.000000  13.135000    2.035000   2.335000          19.500000
# 75%     3.000000  13.730000    3.262500   2.540000          21.625000
# max     3.000000  14.830000    5.510000   3.230000          28.500000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count   88.000000      88.000000   88.000000             88.000000
# mean    98.022727       2.237841    1.975227              0.377841
# std     12.918825       0.646418    1.091060              0.129929
# ...

# %% [markdown]
# Em relação à diferença dos valores observados é possível em observar que, em determinadas amostras (às vezes inferiores), o valor se aproxima mais do valor real do que em amostras mais próximas do valor original. Por exemplo, as amostras de 30 e 10% apresentaram valores percentualmente mais aproximados da população total do que a amostra de 50%. Isso pode se dar por algum valor extremo dentro da população que acaba influenciando as saídas quando a amostra retirada é grande.
